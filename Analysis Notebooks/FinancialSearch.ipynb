# %%
# Create and embedding for searching through past for similar condition finding
import os,sys,inspect
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint
from sklearn.preprocessing import MinMaxScaler
from kats.consts import TimeSeriesData
from kats.tsfeatures.tsfeatures import TsFeatures
import itertools
from decimal import Decimal
from IPython.display import clear_output
import faiss  
import yfinance as yf

import warnings
warnings.simplefilter(action='ignore')

# %%
path= '../datasets/dow50.csv'
dow = pd.read_csv(path)

# %%
google = yf.Ticker('GOOGL')

# %%
google.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2004-08-19  2.502503  2.604104  2.401401  2.511011   2.511011  893181924
# 2004-08-20  2.527778  2.729730  2.515015  2.710460   2.710460  456686856
# 2004-08-23  2.771522  2.839840  2.728979  2.737738   2.737738  365122512
# 2004-08-24  2.783784  2.792793  2.591842  2.624374   2.624374  304946748
# 2004-08-25  2.626627  2.702703  2.599600  2.652653   2.652653  183772044

# %%
dxy = yf.Ticker('dxy')

# %%
dxy.history(period='1m')
# Out:
# - DXY: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
google.info
# Out:
# {'zip': '94043',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 174014,
# ...

# %%
path= '../data/snpstocks.csv'
snp = pd.read_csv(path)

# %%
url = "https://raw.githubusercontent.com/datasets/nasdaq-listings/master/data/nasdaq-listed.csv"
nas = pd.read_csv(url)

# %%
nas.head()
# Out:
#   Symbol                    Company Name  \
# 0   AABA                    Altaba Inc.
# 1    AAL  American Airlines Group, Inc.
# 2   AAME  Atlantic American Corporation
# 3   AAOI  Applied Optoelectronics, Inc.
# 4   AAON                     AAON, Inc.
#
#                                   Security Name Market Category Test Issue  \
# 0                    Altaba Inc. - Common Stock               Q          N
# 1  American Airlines Group, Inc. - Common Stock               Q          N
# 2  Atlantic American Corporation - Common Stock               G          N
# 3  Applied Optoelectronics, Inc. - Common Stock               G          N
# 4                     AAON, Inc. - Common Stock               Q          N
#
#   Financial Status  Round Lot Size ETF NextShares
# 0                N           100.0   N          N
# 1                N           100.0   N          N
# 2                N           100.0   N          N
# 3                N           100.0   N          N
# ...

# %%
snp.head()
# Out:
#   Symbol           Description      Category2  Category3  \
# 0   AAPL             Apple Inc  Common stocks  Large cap
# 1   MSFT        Microsoft Corp  Common stocks  Large cap
# 2   GOOG  Alphabet Inc Class C  Common stocks  Large cap
# 3  GOOGL  Alphabet Inc Class A  Common stocks  Large cap
# 4   AMZN       Amazon.Com Inc.  Common stocks  Large cap
#
#               GICS Sector          Market cap Dividend yield  \
# 0  Information Technology  $2,352,758,092,800          0.61%
# 1  Information Technology  $1,858,506,654,502          0.99%
# 2  Communication Services  $1,238,156,140,000          0.00%
# 3  Communication Services  $1,238,156,140,000          0.00%
# 4  Consumer Discretionary  $1,232,184,755,237          0.00%
#
#    Price to TTM earnings  Price to TTM sales  Price to book value   Action
# 0                  22.93                6.10                34.68  Analyze
# 1                  25.40                9.65                11.30  Analyze
# ...

# %%
snpnas = pd.concat([nas, snp])

# %%
snpnas.describe()
# Out:
#        Round Lot Size  Price to TTM earnings  Price to TTM sales  \
# count          3370.0             503.000000          503.000000
# mean            100.0              24.203141            3.823757
# std               0.0              30.597617            3.586767
# min             100.0            -116.200000            0.000000
# 25%             100.0              10.310000            1.360000
# 50%             100.0              19.180000            2.770000
# 75%             100.0              29.635000            4.790000
# max             100.0             378.430000           23.290000
#
#        Price to book value
# count           503.000000
# mean              6.749642
# std              44.472945
# min            -173.950000
# 25%               1.530000
# 50%               2.930000
# 75%               6.055000
# max             787.940000

# %%
snas = snpnas.drop_duplicates(subset='Symbol')

# %%
snas.to_csv('../datasets/snpnasstocks.csv',index=0)
